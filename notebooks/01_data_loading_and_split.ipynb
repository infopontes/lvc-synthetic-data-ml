# %%
# Data Loading and Stratified Split for LVC Dataset

"""
Project: LVC Synthetic Data ML
Author: Marcelo Pontes Rodrigues

Objective:
- Load dataset
- Perform preprocessing
- Apply stratified train/test split using multiple seeds
"""
# Out:
# '\nProject: LVC Synthetic Data ML\nAuthor: Marcelo Pontes Rodrigues\n\nObjective:\n- Load dataset\n- Perform preprocessing\n- Apply stratified train/test split using multiple seeds\n'

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
SEEDS = [41, 42, 46]
TEST_SIZE = 0.3

TARGET = "diagnosis"

# %%
df = pd.read_csv("../data/raw/leish_dataset.csv")

print("Shape:", df.shape)
df.head()

# %%
print(df[TARGET].value_counts())
print(df[TARGET].value_counts(normalize=True))

# %%
X = df.drop(columns=[TARGET])
y = df[TARGET]

# %%
splits = {}

for seed in SEEDS:
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=TEST_SIZE,
        stratify=y,
        random_state=seed
    )

    splits[seed] = {
        "X_train": X_train,
        "X_test": X_test,
        "y_train": y_train,
        "y_test": y_test
    }

    print(f"\nSeed: {seed}")
    print("Train shape:", X_train.shape)
    print("Test shape:", X_test.shape)
    print("Train distribution:\n", y_train.value_counts(normalize=True))
    print("Test distribution:\n", y_test.value_counts(normalize=True))

# %%
for seed in SEEDS:
    train_idx = set(splits[seed]["X_train"].index)
    test_idx = set(splits[seed]["X_test"].index)

    intersection = train_idx.intersection(test_idx)

    print(f"Seed {seed} - Overlap:", len(intersection))
